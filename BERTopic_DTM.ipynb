# %% [markdown]
# <a href="https://colab.research.google.com/github/Anenmi/practice/blob/main/BERTopic_DTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tutorial** - Dynamic Topic Modeling with Trump's Tweets
# (last updated 11-09-2022)
#
# In this tutorial we will be using Dynamic Topic Modeling with BERTopic to visualize how topics in Trump's Tweets have evolved over time. These topics will be visualized and thoroughly explored.
#
# ## Dynamic Topic Models
# Dynamic topic models can be used to analyze the evolution of topics of a collection of documents over time.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**
# For this tutorial, we will be needing to extract all Trump's Tweet from his @realDonalTrump account. We will be removing all retweet and focus on his original tweets.
#
# Moreover, since we are looking at his tweets over time, we will be saving all timestamps related to his tweets.

# %%
import re
import pandas as pd
from datetime import datetime

# Load data
trump = pd.read_csv('https://drive.google.com/uc?export=download&id=1xRKHaP-QwACMydlDnyFPEaFdtskJuBa6')

# Filter
trump.text = trump.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
trump.text = trump.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
trump.text = trump.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
trump = trump.loc[(trump.isRetweet == "f") & (trump.text != ""), :]
timestamps = trump.date.to_list()
tweets = trump.text.to_list()

# %%
tweets[0]
# Out:
# 'republicans and democrats have both created our economic problems'

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all tweets. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those tweets.

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=35, verbose=True)
topics, _ = topic_model.fit_transform(tweets)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=244715968.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=1418.0, style=ProgressStyle(description_wid…
# 2021-04-26 10:01:08,287 - BERTopic - Transformed documents to Embeddings
# 2021-04-26 10:02:04,547 - BERTopic - Reduced dimensionality with UMAP
# 2021-04-26 10:02:09,994 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                   Name
# 0     -1  15084                        -1_the_to_of_is
# 1      0   3143               0_run_president_trump_mr
# 2      1   1885            1_crowd_carolina_join_thank
# 3      2   1124       2_border_wall_mexico_immigration
# 4      3   1009    3_entrepreneurs_yourself_think_your
# 5      4    828          4_china_tariffs_trade_chinese
# 6      5    690       5_golf_course_scotland_turnberry
# 7      6    635  6_obamacare_healthcare_repeal_website
# 8      7    632          7_hillary_clinton_crooked_she
# 9      8    579                        8_amp_it_you_to

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(4)
# Out:
# [('china', 0.05289416225000891),
#  ('tariffs', 0.024471004754487165),
#  ('trade', 0.02437576425026641),
#  ('chinese', 0.013643270667358017),
#  ('us', 0.011206804363719649),
#  ('farmers', 0.01113584970813823),
#  ('our', 0.010197907480148342),
#  ('deal', 0.010014612658730073),
#  ('we', 0.009043537683534882),
#  ('countries', 0.00901653033214627)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map. This allows us to judge visually whether the basic topics are sufficient before proceeding to creating the topics over time.

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7e2c1f5e-ff4e-4b2b-b5a1-c022d0bf5e3a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e2c1f5e-ff4e-4b2b-b5a1-c022d0bf5e3a")) {                    Plotly.newPlot(                        "7e2c1f5e-ff4e-4b2b-b5a1-c022d0bf5e3a",                        [{"customdata":[[0,"run | president | trump | mr | donald",3143],[1,"crowd | carolina | join | thank | rally",1885],[2,"border | wall | mexico | immigration | security",1124],[3,"entrepreneurs | yourself | think | your | success",1009],[4,"china | tariffs | trade | chinese | us",828],[5,"golf | course | scotland | turnberry | club",690],[6,"obamacare | healthcare | repeal | website | premiums",635],[7,"hillary | clinton | crooked | she | bernie",632],[8,"amp | it | you | to | we",579],[9,"media | fake | news | failing | dishonest",577],[10,"veterans | honor | heroes | our | day",530],[11,"celebapprentice | celebrityapprentice | season | show | boardroom",504],[12,"endorsement | complete | congressman | total | amendment",468],[13,"thanks | nice | it | so | question",391],[14,"apprentice | celebrity | nbc | season | episode",384],[15,"poll | polls | numbers | lead | carson",371],[16,"thanks | thank | you | david | dan",362],[17,"thanks | dope | appreciate | think | even",358],[18,"ballots | election | fraud | mail | rigged",328],[19,"hotel | vegas | hotels | rooms | star",325],[20,"biden | joe | sleepy | fracking | he",323],[21,"ties | macy | shirts | collection | tie",315],[22,"democrats | party | republicans | radical | republican",311],[23,"america | again | together | we | make",292],[24,"thank | you | fifth | appreciate | th",289],[25,"melania | ivanka | lady | daughter | first",279],[26,"syria | isis | turkey | kurds | attack",276],[27,"chicago | sign | tower | building | love",270],[28,"via | donald | by | trump | cpac",253],[29,"tax | taxes | cuts | cut | raise",250],[30,"iran | nuclear | iranian | deal | sanctions",246],[31,"book | read | books | new | reading",245],[32,"oil | gas | opec | prices | keystone",241],[33,"wind | turbines | scotland | ugly | bird",239],[34,"korea | north | kim | jong | un",229],[35,"obama | president | he | barack | barackobama",220],[36,"coronavirus | testing | covid | cases | virus",209],[37,"interviewed | enjoy | tonight | at | be",207],[38,"nfl | anthem | brady | football | players",192],[39,"interview | discussing | my | iontv | newsmax",188],[40,"birthday | happy | th | wishes | retweet",186],[41,"miss | pageant | universe | missuniverse | usa",176],[42,"doral | monster | blue | miami | national",174],[43,"mueller | report | collusion | obstruction | no",173],[44,"christmas | happy | merry | easter | thanksgiving",170],[45,"debt | budget | ceiling | trillion | deficit",162],[46,"impeachment | impeach | hoax | nothing | democrats",162],[47,"makeamericagreatagain | trump | trumpforpresident | america | donald",156],[48,"cnn | ratings | news | msnbc | fake",150],[49,"true | so | sadly | point | sum",146],[50,"schiff | whistleblower | adam | shifty | call",145],[51,"debate | debates | drudge | won | poll",143],[52,"enjoy | at | monday | tonight | tune",142],[53,"secretary | general | pleased | acting | announce",142],[54,"letterman | howard | stern | show | david",142],[55,"conference | press | white | meeting | house",140],[56,"anarchists | portland | protesters | mayor | minneapolis",136],[57,"stock | market | dow | high | record",134],[58,"warming | global | climate | freezing | cold",133],[59,"collusion | russia | hunt | witch | russian",133],[60,"tweets | twitter | tweet | followers | account",129],[61,"lawyer | lawsuit | sue | case | university",128],[62,"again | america | make | great | subjected",124],[63,"court | supreme | justices | judges |  ...

# %% [markdown]
# ## Topics over Time
# Before we start with the Dynamic Topic Modeling step, it is important that you are satisfied with the topics that were created previously. We are going to be using those specific topics as a base for Dynamic Topic Modeling.
#
# Thus, this step will essentially show you how the topics that were defined previously have evolved over time.

# %% [markdown]
# There are a few important parameters that you should take note of, namely:
#
# * `docs`
#   * These are the tweets that we are using
# * `timestamps`
#   * The timestamp of each tweet/document
# * `global_tuning`
#   * Whether to average the topic representation of a topic at time *t* with its global topic representation
# * `evolution_tuning`
#   * Whether to average the topic representation of a topic at time *t* with the topic representation of that topic at time *t-1*
# * `nr_bins`
#   * The number of bins to put our timestamps into. It is computationally inefficient to extract the topics at thousands of different timestamps. Therefore, it is advised to keep this value below 20.

# %%
topics_over_time = topic_model.topics_over_time(docs=tweets, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 20it [00:06,  2.99it/s]

# %% [markdown]
# ## Visualize Topics over Time
# After having created our `topics_over_time`, we will have to visualize those topics as accessing them becomes a bit more difficult with the added temporal dimension.
#
# To do so, we are going to visualize the distribution of topics over time based on their frequency. Doing so allows us to see how the topics have evolved over time. Make sure to hover over any point to see how the topic representation at time *t* differs from the global topic representation.

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3c8f9a31-cebc-4cdd-b179-97f17c5d7326" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c8f9a31-cebc-4cdd-b179-97f17c5d7326")) {                    Plotly.newPlot(                        "3c8f9a31-cebc-4cdd-b179-97f17c5d7326",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: execute, imagination, direct, donald, precipice","<b>Topic 0</b><br>Words: shouldtrumprun, instance, usually, solved, proper","<b>Topic 0</b><br>Words: defined, teaches, require, strong, cont","<b>Topic 0</b><br>Words: indonesian, business, president, need, run","<b>Topic 0</b><br>Words: run, president, mr, trump, donald","<b>Topic 0</b><br>Words: run, president, trump, you, mr","<b>Topic 0</b><br>Words: run, president, please, trump, mr","<b